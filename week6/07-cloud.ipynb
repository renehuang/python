# %% [markdown]
# # cloud computing
# - Amazon Web Services has a comprehensive python interface, 'boto3' for controlling the cloud
# - [interesting article about how Netflix uses Python on AWS](http://techblog.netflix.com/2013/03/python-at-netflix.html)
# - [docs](http://boto3.readthedocs.io/en/latest/reference/services/)

# %% [markdown]
# # Connect to AWS and get status

# %%
from boto3 import *

ec2c = client('ec2')

# %%
# nothing running now

ins = ec2c.describe_instances(Filters=[{'Name': 'instance-state-name', 'Values': ['running']}])
ins
# Out:
# {'Reservations': [{'Groups': [],
#    'Instances': [{'AmiLaunchIndex': 0,
#      'Architecture': 'x86_64',
#      'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#        'Ebs': {'AttachTime': datetime.datetime(2016, 5, 17, 21, 13, 48, tzinfo=tzutc()),
#         'DeleteOnTermination': True,
#         'Status': 'attached',
#         'VolumeId': 'vol-de3efb0e'}},
#       {'DeviceName': '/dev/sdf',
#        'Ebs': {'AttachTime': datetime.datetime(2016, 5, 18, 20, 48, 38, tzinfo=tzutc()),
#         'DeleteOnTermination': False,
#         'Status': 'attached',
#         'VolumeId': 'vol-146fadc4'}}],
#      'ClientToken': 'vLCQR1463519627573',
#      'EbsOptimized': False,
#      'Hypervisor': 'xen',
#      'ImageId': 'ami-fce3c696',
#      'InstanceId': 'i-0ea51fd37eb61ca9a',
#      'InstanceType': 't2.medium',
#      'KeyName': 'lstead-aws',
#      'LaunchTime': datetime.datetime(2016, 5, 18, 20, 48, 52, tzinfo=tzutc()),
#      'Monitoring': {'State': 'disabled'},
#      'NetworkInterfaces': [{'Association': {'IpOwnerId': '674776699098',
#         'PublicDnsName': 'ec2-52-203-160-68.compute-1.amazonaws.com',
#         'PublicIp': '52.203.160.68'},
#        'Attachment': {'AttachTime': datetime.datetime(2016, 5, 17, 21, 13, 48, tzinfo=tzutc()),
#         'AttachmentId': 'eni-attach-222778d2',
#         'DeleteOnTermination': True,
#         'DeviceIndex': 0,
#         'Status': 'attached'},
#        'Description': 'Primary network interface',
#        'Groups': [{'GroupId': 'sg-9e8e5ce5', 'GroupName': 'launch-wizard-7'}],
#        'Ipv6Addresses': [],
#        'MacAddress': '12:1a:a2:08:06:5b',
#        'NetworkInterfaceId': 'eni-34ee9613',
#        'OwnerId': '674776699098',
#        'PrivateDnsName': 'ip-172-31-59-18.ec2.internal',
#        'PrivateIpAddress': '172.31.59.18',
#        'PrivateIpAddresses': [{'Association': {'IpOwnerId': '674776699098',
#           'PublicDnsName': 'ec2-52-203-160-68.compute-1.amazonaws.com',
#           'PublicIp': '52.203.160.68'},
#          'Primary': True,
#          'PrivateDnsName': 'ip-172-31-59-18.ec2.internal',
#          'PrivateIpAddress': '172.31.59.18'}],
#        'SourceDestCheck': True,
#        'Status': 'in-use',
#        'SubnetId': 'subnet-881a9aa2',
#        'VpcId': 'vpc-dc8493b8'}],
#      'Placement': {'AvailabilityZone': 'us-east-1c',
#       'GroupName': '',
#       'Tenancy': 'default'},
#      'PrivateDnsName': 'ip-172-31-59-18.ec2.internal',
#      'PrivateIpAddress': '172.31.59.18',
#      'ProductCodes': [],
#      'PublicDnsName': 'ec2-52-203-160-68.compute-1.amazonaws.com',
#      'PublicIpAddress': '52.203.160.68',
#      'RootDeviceName': '/dev/sda1',
#      'RootDeviceType': 'ebs',
#      'SecurityGroups': [{'GroupId': 'sg-9e8e5ce5',
#        'GroupName': 'launch-wizard-7'}],
#      'SourceDestCheck': True,
#      'State': {'Code': 16, 'Name': 'running'},
#      'StateTransitionReason': '',
#      'SubnetId': 'subnet-881a9aa2',
#      'Tags': [{'Key': 'Name', 'Value': 'nginx-nfs'},
#       {'Key': 'opsworks:layer:nfs-nginx', 'Value': 'nfs-nginx'},
#       {'Key': 'opsworks:stack', 'Value': 'Default Stack'},
#       {'Key': 'opsworks:instance', 'Value': 'ip-172-31-59-18'}],
#      'VirtualizationType': 'hvm',
#      'VpcId': 'vpc-dc8493b8'}],
#    'OwnerId': '674776699098',
#    'ReservationId': 'r-0270c5272a1993d3e'},
#   {'Groups': [],
#    'Instances': [{'AmiLaunchIndex': 0,
#      'Architecture': 'x86_64',
#      'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#        'Ebs': {'AttachTime': datetime.datetime(2016, 5, 17, 14, 55, 53, tzinfo=tzutc()),
#         'DeleteOnTermination': True,
#         'Status': 'attached',
#         'VolumeId': 'vol-ebc03b3b'}},
#       {'DeviceName': '/dev/sdf',
#        'Ebs': {'AttachTime': datetime.datetime(2016, 5, 18, 20, 47, 58, tzinfo=tzutc()),
#         'DeleteOnTermination': False,
#         'Status': 'attached',
#         'VolumeId': 'vol-d06cae00'}}],
#      'ClientToken': '146349693967329059',
#      'EbsOptimized': False,
#      'Hypervisor': 'xen',
#      'ImageId': 'ami-e0b3568d',
#      'InstanceId': 'i-015b9e0f08e6cae43',
#      'InstanceType': 'g2.2xlarge',
#      'KeyName': 'lstead-aws',
#      'LaunchTime': datetime.datetime(2016, 10, 25, 13, 7, 3, tzinfo=tzutc()),
#      'Monitoring': {'State': 'disabled'},
#      'NetworkInterfaces': [{'Association': {'IpOwnerId': '674776699098',
#         'PublicDnsName': 'ec2-52-201-56-125.compute-1.amazonaws.com',
#         'PublicIp': '52.201.56.125'},
#        'Attachment': {'AttachTime': datetime.datetime(2016, 5, 17, 14, 55, 52, tzinfo=tzutc()),
#         'AttachmentId': 'eni-attach-c7a6f437',
#         'DeleteOnTermination': True,
#         'DeviceIndex': 0,
#         'Status': 'attached'},
#        'Description': 'Primary network interface',
#        'Groups': [{'GroupId': 'sg-4983a931',
#          'GroupName': 'Bitfusion Ubuntu 14 Cuda 7 -GPU--0-01--AutogenByAWSMP-'}],
#        'Ipv6Addresses': [],
#        'MacAddress': '12:a6:79:e0:1c:df',
#        'NetworkInterfaceId': 'eni-6bc2bd4c',
#        'OwnerId': '674776699098',
#        'PrivateDnsName': 'ip-172-31-57-246.ec2.internal',
#        'PrivateIpAddress': '172.31.57.246',
#        'PrivateIpAddresses': [{'Association': {'IpOwnerId': '674776699098',
#           'PublicDnsName': 'ec2-52-201-56-125.compute-1.amazonaws.com',
#           'PublicIp': '52.201.56.125'},
#          'Primary': True,
#          'PrivateDnsName': 'ip-172-31-57-246.ec2.internal',
#          'PrivateIpAddress': '172.31.57.246'}],
#        'SourceDestCheck': True,
#        'Status': 'in-use',
#        'SubnetId': 'subnet-881a9aa2',
#        'VpcId': 'vpc-dc8493b8'}],
#      'Placement': {'AvailabilityZone': 'us-east-1c',
#       'GroupName': '',
#       'Tenancy': 'default'},
#      'PrivateDnsName': 'ip-172-31-57-246.ec2.internal',
#      'PrivateIpAddress': '172.31.57.246',
#      'ProductCodes': [{'ProductCodeId': 'd7b4x2lsogqounxst4jkrmdag',
#        'ProductCodeType': 'marketplace'}],
#      'PublicDnsName': 'ec2-52-201-56-125.compute-1.amazonaws.com',
#      'PublicIpAddress': '52.201.56.125',
#      'RootDeviceName': '/dev/sda1',
#      'RootDeviceType': 'ebs',
#      'SecurityGroups': [{'GroupId': 'sg-4983a931',
#        'GroupName': 'Bitfusion Ubuntu 14 Cuda 7 -GPU--0-01--AutogenByAWSMP-'}],
#      'SourceDestCheck': True,
#      'State': {'Code': 16, 'Name': 'running'},
#      'StateTransitionReason': '',
#      'SubnetId': 'subnet-881a9aa2',
#      'Tags': [{'Key': 'Role', 'Value': 'development'},
#       {'Key': 'opsworks:layer:gpu', 'Value': 'Backend GPU Machine'},
#       {'Key': 'Name', 'Value': 'loptix-dev'},
#       {'Key': 'opsworks:instance', 'Value': 'ip-172-31-57-246'},
#       {'Key': 'opsworks:stack', 'Value': 'Default Stack'}],
#      'VirtualizationType': 'hvm',
#      'VpcId': 'vpc-dc8493b8'}],
#    'OwnerId': '674776699098',
#    'ReservationId': 'r-09c7613e06354a10b'},
#   {'Groups': [],
#    'Instances': [{'AmiLaunchIndex': 0,
#      'Architecture': 'x86_64',
#      'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#        'Ebs': {'AttachTime': datetime.datetime(2016, 5, 26, 19, 38, 6, tzinfo=tzutc()),
#         'DeleteOnTermination': True,
#         'Status': 'attached',
#         'VolumeId': 'vol-f0f3a15b'}}],
#      'ClientToken': 'FSpFx1464291484490',
#      'EbsOptimized': False,
#      'Hypervisor': 'xen',
#      'ImageId': 'ami-e0b3568d',
#      'InstanceId': 'i-04fe4b1ff191e4d99',
#      'InstanceType': 'g2.2xlarge',
#      'KeyName': 'lstead-aws',
#      'LaunchTime': datetime.datetime(2016, 10, 19, 0, 16, 47, tzinfo=tzutc()),
#      'Monitoring': {'State': 'disabled'},
#      'NetworkInterfaces': [{'Association': {'IpOwnerId': 'amazon',
#         'PublicDnsName': 'ec2-54-227-184-215.compute-1.amazonaws.com',
#         'PublicIp': '54.227.184.215'},
#        'Attachment': {'AttachTime': datetime.datetime(2016, 5, 26, 19, 38, 5, tzinfo=tzutc()),
#         'AttachmentId': 'eni-attach-6361dcb8',
#         'DeleteOnTermination': True,
#         'DeviceIndex': 0,
#         'Status': 'attached'},
#        'Description': '',
#        'Groups': [{'GroupId': 'sg-5ffb5224', 'GroupName': 'gpu-backends'}],
#        'Ipv6Addresses': [],
#        'MacAddress': '0a:05:1d:21:1d:97',
#        'NetworkInterfaceId': 'eni-934cd0d0',
#        'OwnerId': '674776699098',
#        'PrivateDnsName': 'ip-172-31-12-16.ec2.internal',
#        'PrivateIpAddress': '172.31.12.16',
#        'PrivateIpAddresses': [{'Association': {'IpOwnerId': 'amazon',
#           'PublicDnsName': 'ec2-54-227-184-215.compute-1.amazonaws.com',
#           'PublicIp': '54.227.184.215'},
#          'Primary': True,
#          'PrivateDnsName': 'ip-172-31-12-16.ec2.internal',
#          'PrivateIpAddress': '172.31.12.16'}],
#        'SourceDestCheck': True,
#        'Status': 'in-use',
#        'SubnetId': 'subnet-b2e99ac4',
#        'VpcId': 'vpc-dc8493b8'}],
#      'Placement': {'AvailabilityZone': 'us-east-1d',
#       'GroupName': '',
#       'Tenancy': 'default'},
#      'PrivateDnsName': 'ip-172-31-12-16.ec2.internal',
#      'PrivateIpAddress': '172.31.12.16',
#      'ProductCodes': [{'ProductCodeId': 'd7b4x2lsogqounxst4jkrmdag',
#        'ProductCodeType': 'marketplace'}],
#      'PublicDnsName': 'ec2-54-227-184-215.compute-1.amazonaws.com',
#      'PublicIpAddress': '54.227.184.215',
#      'RootDeviceName': '/dev/sda1',
#      'RootDeviceType': 'ebs',
#      'SecurityGroups': [{'GroupId': 'sg-5ffb5224',
#        'GroupName': 'gpu-backends'}],
#      'SourceDestCheck': True,
#      'State': {'Code': 16, 'Name': 'running'},
#      'StateTransitionReason': '',
#      'SubnetId': 'subnet-b2e99ac4',
#      'Tags': [{'Key': 'opsworks:stack', 'Value': 'Default Stack'},
#       {'Key': 'Name', 'Value': 'loptix1'},
#       {'Key': 'opsworks:layer:gpu', 'Value': 'Backend GPU Machine'},
#       {'Key': 'opsworks:instance', 'Value': 'loptix1'},
#       {'Key': 'Role', 'Value': 'production'}],
#      'VirtualizationType': 'hvm',
#      'VpcId': 'vpc-dc8493b8'}],
#    'OwnerId': '674776699098',
#    'ReservationId': 'r-00923a48ab8a83bce'}],
#  'ResponseMetadata': {'HTTPHeaders': {'content-type': 'text/xml;charset=UTF-8',
#    'date': 'Thu, 02 Mar 2017 01:47:37 GMT',
#    'server': 'AmazonEC2',
#    'transfer-encoding': 'chunked',
#    'vary': 'Accept-Encoding'},
#   'HTTPStatusCode': 200,
#   'RequestId': '1c7ab23d-c87a-42c6-85c2-8952a5b9b288',
#   'RetryAttempts': 0}}

# %%
ins['Reservations']
# Out:
# [{'Groups': [],
#   'Instances': [{'AmiLaunchIndex': 0,
#     'Architecture': 'x86_64',
#     'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#       'Ebs': {'AttachTime': datetime.datetime(2016, 5, 17, 21, 13, 48, tzinfo=tzutc()),
#        'DeleteOnTermination': True,
#        'Status': 'attached',
#        'VolumeId': 'vol-de3efb0e'}},
#      {'DeviceName': '/dev/sdf',
#       'Ebs': {'AttachTime': datetime.datetime(2016, 5, 18, 20, 48, 38, tzinfo=tzutc()),
#        'DeleteOnTermination': False,
#        'Status': 'attached',
#        'VolumeId': 'vol-146fadc4'}}],
#     'ClientToken': 'vLCQR1463519627573',
#     'EbsOptimized': False,
#     'Hypervisor': 'xen',
#     'ImageId': 'ami-fce3c696',
#     'InstanceId': 'i-0ea51fd37eb61ca9a',
#     'InstanceType': 't2.medium',
#     'KeyName': 'lstead-aws',
#     'LaunchTime': datetime.datetime(2016, 5, 18, 20, 48, 52, tzinfo=tzutc()),
#     'Monitoring': {'State': 'disabled'},
#     'NetworkInterfaces': [{'Association': {'IpOwnerId': '674776699098',
#        'PublicDnsName': 'ec2-52-203-160-68.compute-1.amazonaws.com',
#        'PublicIp': '52.203.160.68'},
#       'Attachment': {'AttachTime': datetime.datetime(2016, 5, 17, 21, 13, 48, tzinfo=tzutc()),
#        'AttachmentId': 'eni-attach-222778d2',
#        'DeleteOnTermination': True,
#        'DeviceIndex': 0,
#        'Status': 'attached'},
#       'Description': 'Primary network interface',
#       'Groups': [{'GroupId': 'sg-9e8e5ce5', 'GroupName': 'launch-wizard-7'}],
#       'Ipv6Addresses': [],
#       'MacAddress': '12:1a:a2:08:06:5b',
#       'NetworkInterfaceId': 'eni-34ee9613',
#       'OwnerId': '674776699098',
#       'PrivateDnsName': 'ip-172-31-59-18.ec2.internal',
#       'PrivateIpAddress': '172.31.59.18',
#       'PrivateIpAddresses': [{'Association': {'IpOwnerId': '674776699098',
#          'PublicDnsName': 'ec2-52-203-160-68.compute-1.amazonaws.com',
#          'PublicIp': '52.203.160.68'},
#         'Primary': True,
#         'PrivateDnsName': 'ip-172-31-59-18.ec2.internal',
#         'PrivateIpAddress': '172.31.59.18'}],
#       'SourceDestCheck': True,
#       'Status': 'in-use',
#       'SubnetId': 'subnet-881a9aa2',
#       'VpcId': 'vpc-dc8493b8'}],
#     'Placement': {'AvailabilityZone': 'us-east-1c',
#      'GroupName': '',
#      'Tenancy': 'default'},
#     'PrivateDnsName': 'ip-172-31-59-18.ec2.internal',
#     'PrivateIpAddress': '172.31.59.18',
#     'ProductCodes': [],
#     'PublicDnsName': 'ec2-52-203-160-68.compute-1.amazonaws.com',
#     'PublicIpAddress': '52.203.160.68',
#     'RootDeviceName': '/dev/sda1',
#     'RootDeviceType': 'ebs',
#     'SecurityGroups': [{'GroupId': 'sg-9e8e5ce5',
#       'GroupName': 'launch-wizard-7'}],
#     'SourceDestCheck': True,
#     'State': {'Code': 16, 'Name': 'running'},
#     'StateTransitionReason': '',
#     'SubnetId': 'subnet-881a9aa2',
#     'Tags': [{'Key': 'Name', 'Value': 'nginx-nfs'},
#      {'Key': 'opsworks:layer:nfs-nginx', 'Value': 'nfs-nginx'},
#      {'Key': 'opsworks:stack', 'Value': 'Default Stack'},
#      {'Key': 'opsworks:instance', 'Value': 'ip-172-31-59-18'}],
#     'VirtualizationType': 'hvm',
#     'VpcId': 'vpc-dc8493b8'}],
#   'OwnerId': '674776699098',
#   'ReservationId': 'r-0270c5272a1993d3e'},
#  {'Groups': [],
#   'Instances': [{'AmiLaunchIndex': 0,
#     'Architecture': 'x86_64',
#     'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#       'Ebs': {'AttachTime': datetime.datetime(2016, 5, 17, 14, 55, 53, tzinfo=tzutc()),
#        'DeleteOnTermination': True,
#        'Status': 'attached',
#        'VolumeId': 'vol-ebc03b3b'}},
#      {'DeviceName': '/dev/sdf',
#       'Ebs': {'AttachTime': datetime.datetime(2016, 5, 18, 20, 47, 58, tzinfo=tzutc()),
#        'DeleteOnTermination': False,
#        'Status': 'attached',
#        'VolumeId': 'vol-d06cae00'}}],
#     'ClientToken': '146349693967329059',
#     'EbsOptimized': False,
#     'Hypervisor': 'xen',
#     'ImageId': 'ami-e0b3568d',
#     'InstanceId': 'i-015b9e0f08e6cae43',
#     'InstanceType': 'g2.2xlarge',
#     'KeyName': 'lstead-aws',
#     'LaunchTime': datetime.datetime(2016, 10, 25, 13, 7, 3, tzinfo=tzutc()),
#     'Monitoring': {'State': 'disabled'},
#     'NetworkInterfaces': [{'Association': {'IpOwnerId': '674776699098',
#        'PublicDnsName': 'ec2-52-201-56-125.compute-1.amazonaws.com',
#        'PublicIp': '52.201.56.125'},
#       'Attachment': {'AttachTime': datetime.datetime(2016, 5, 17, 14, 55, 52, tzinfo=tzutc()),
#        'AttachmentId': 'eni-attach-c7a6f437',
#        'DeleteOnTermination': True,
#        'DeviceIndex': 0,
#        'Status': 'attached'},
#       'Description': 'Primary network interface',
#       'Groups': [{'GroupId': 'sg-4983a931',
#         'GroupName': 'Bitfusion Ubuntu 14 Cuda 7 -GPU--0-01--AutogenByAWSMP-'}],
#       'Ipv6Addresses': [],
#       'MacAddress': '12:a6:79:e0:1c:df',
#       'NetworkInterfaceId': 'eni-6bc2bd4c',
#       'OwnerId': '674776699098',
#       'PrivateDnsName': 'ip-172-31-57-246.ec2.internal',
#       'PrivateIpAddress': '172.31.57.246',
#       'PrivateIpAddresses': [{'Association': {'IpOwnerId': '674776699098',
#          'PublicDnsName': 'ec2-52-201-56-125.compute-1.amazonaws.com',
#          'PublicIp': '52.201.56.125'},
#         'Primary': True,
#         'PrivateDnsName': 'ip-172-31-57-246.ec2.internal',
#         'PrivateIpAddress': '172.31.57.246'}],
#       'SourceDestCheck': True,
#       'Status': 'in-use',
#       'SubnetId': 'subnet-881a9aa2',
#       'VpcId': 'vpc-dc8493b8'}],
#     'Placement': {'AvailabilityZone': 'us-east-1c',
#      'GroupName': '',
#      'Tenancy': 'default'},
#     'PrivateDnsName': 'ip-172-31-57-246.ec2.internal',
#     'PrivateIpAddress': '172.31.57.246',
#     'ProductCodes': [{'ProductCodeId': 'd7b4x2lsogqounxst4jkrmdag',
#       'ProductCodeType': 'marketplace'}],
#     'PublicDnsName': 'ec2-52-201-56-125.compute-1.amazonaws.com',
#     'PublicIpAddress': '52.201.56.125',
#     'RootDeviceName': '/dev/sda1',
#     'RootDeviceType': 'ebs',
#     'SecurityGroups': [{'GroupId': 'sg-4983a931',
#       'GroupName': 'Bitfusion Ubuntu 14 Cuda 7 -GPU--0-01--AutogenByAWSMP-'}],
#     'SourceDestCheck': True,
#     'State': {'Code': 16, 'Name': 'running'},
#     'StateTransitionReason': '',
#     'SubnetId': 'subnet-881a9aa2',
#     'Tags': [{'Key': 'Role', 'Value': 'development'},
#      {'Key': 'opsworks:layer:gpu', 'Value': 'Backend GPU Machine'},
#      {'Key': 'Name', 'Value': 'loptix-dev'},
#      {'Key': 'opsworks:instance', 'Value': 'ip-172-31-57-246'},
#      {'Key': 'opsworks:stack', 'Value': 'Default Stack'}],
#     'VirtualizationType': 'hvm',
#     'VpcId': 'vpc-dc8493b8'}],
#   'OwnerId': '674776699098',
#   'ReservationId': 'r-09c7613e06354a10b'},
#  {'Groups': [],
#   'Instances': [{'AmiLaunchIndex': 0,
#     'Architecture': 'x86_64',
#     'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#       'Ebs': {'AttachTime': datetime.datetime(2016, 5, 26, 19, 38, 6, tzinfo=tzutc()),
#        'DeleteOnTermination': True,
#        'Status': 'attached',
#        'VolumeId': 'vol-f0f3a15b'}}],
#     'ClientToken': 'FSpFx1464291484490',
#     'EbsOptimized': False,
#     'Hypervisor': 'xen',
#     'ImageId': 'ami-e0b3568d',
#     'InstanceId': 'i-04fe4b1ff191e4d99',
#     'InstanceType': 'g2.2xlarge',
#     'KeyName': 'lstead-aws',
#     'LaunchTime': datetime.datetime(2016, 10, 19, 0, 16, 47, tzinfo=tzutc()),
#     'Monitoring': {'State': 'disabled'},
#     'NetworkInterfaces': [{'Association': {'IpOwnerId': 'amazon',
#        'PublicDnsName': 'ec2-54-227-184-215.compute-1.amazonaws.com',
#        'PublicIp': '54.227.184.215'},
#       'Attachment': {'AttachTime': datetime.datetime(2016, 5, 26, 19, 38, 5, tzinfo=tzutc()),
#        'AttachmentId': 'eni-attach-6361dcb8',
#        'DeleteOnTermination': True,
#        'DeviceIndex': 0,
#        'Status': 'attached'},
#       'Description': '',
#       'Groups': [{'GroupId': 'sg-5ffb5224', 'GroupName': 'gpu-backends'}],
#       'Ipv6Addresses': [],
#       'MacAddress': '0a:05:1d:21:1d:97',
#       'NetworkInterfaceId': 'eni-934cd0d0',
#       'OwnerId': '674776699098',
#       'PrivateDnsName': 'ip-172-31-12-16.ec2.internal',
#       'PrivateIpAddress': '172.31.12.16',
#       'PrivateIpAddresses': [{'Association': {'IpOwnerId': 'amazon',
#          'PublicDnsName': 'ec2-54-227-184-215.compute-1.amazonaws.com',
#          'PublicIp': '54.227.184.215'},
#         'Primary': True,
#         'PrivateDnsName': 'ip-172-31-12-16.ec2.internal',
#         'PrivateIpAddress': '172.31.12.16'}],
#       'SourceDestCheck': True,
#       'Status': 'in-use',
#       'SubnetId': 'subnet-b2e99ac4',
#       'VpcId': 'vpc-dc8493b8'}],
#     'Placement': {'AvailabilityZone': 'us-east-1d',
#      'GroupName': '',
#      'Tenancy': 'default'},
#     'PrivateDnsName': 'ip-172-31-12-16.ec2.internal',
#     'PrivateIpAddress': '172.31.12.16',
#     'ProductCodes': [{'ProductCodeId': 'd7b4x2lsogqounxst4jkrmdag',
#       'ProductCodeType': 'marketplace'}],
#     'PublicDnsName': 'ec2-54-227-184-215.compute-1.amazonaws.com',
#     'PublicIpAddress': '54.227.184.215',
#     'RootDeviceName': '/dev/sda1',
#     'RootDeviceType': 'ebs',
#     'SecurityGroups': [{'GroupId': 'sg-5ffb5224',
#       'GroupName': 'gpu-backends'}],
#     'SourceDestCheck': True,
#     'State': {'Code': 16, 'Name': 'running'},
#     'StateTransitionReason': '',
#     'SubnetId': 'subnet-b2e99ac4',
#     'Tags': [{'Key': 'opsworks:stack', 'Value': 'Default Stack'},
#      {'Key': 'Name', 'Value': 'loptix1'},
#      {'Key': 'opsworks:layer:gpu', 'Value': 'Backend GPU Machine'},
#      {'Key': 'opsworks:instance', 'Value': 'loptix1'},
#      {'Key': 'Role', 'Value': 'production'}],
#     'VirtualizationType': 'hvm',
#     'VpcId': 'vpc-dc8493b8'}],
#   'OwnerId': '674776699098',
#   'ReservationId': 'r-00923a48ab8a83bce'}]

# %%
ins['Reservations'][1]['Instances'][0]['Tags']
# Out:
# [{'Key': 'Role', 'Value': 'development'},
#  {'Key': 'opsworks:layer:gpu', 'Value': 'Backend GPU Machine'},
#  {'Key': 'Name', 'Value': 'loptix-dev'},
#  {'Key': 'opsworks:instance', 'Value': 'ip-172-31-57-246'},
#  {'Key': 'opsworks:stack', 'Value': 'Default Stack'}]

# %%
for res in ins['Reservations']:
    for lst in res['Instances'][0]['Tags']:
        if lst['Key'] == 'Name':
            print(lst['Value'])
# Out:
# nginx-nfs
# loptix-dev
# loptix1

# %% [markdown]
# # bring up two new instances

# %%
# the image we will boot
ami = 'ami-08111162'

ec2r=resource('ec2')

# boot up two machines

ec2r.create_instances(ImageId=ami, 
                    MinCount=2, MaxCount=2,
                    InstanceType='t2.micro')
# Out:
# [ec2.Instance(id='i-077110dd2fb5717a5'),
#  ec2.Instance(id='i-037340254b06008f5')]

# %%
di = ec2c.describe_instances(
     Filters=[{'Name': 'instance-state-name', 'Values': ['running']}])

di
# Out:
# {'Reservations': [{'Groups': [],
#    'Instances': [{'AmiLaunchIndex': 0,
#      'Architecture': 'x86_64',
#      'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#        'Ebs': {'AttachTime': datetime.datetime(2016, 5, 17, 21, 13, 48, tzinfo=tzutc()),
#         'DeleteOnTermination': True,
#         'Status': 'attached',
#         'VolumeId': 'vol-de3efb0e'}},
#       {'DeviceName': '/dev/sdf',
#        'Ebs': {'AttachTime': datetime.datetime(2016, 5, 18, 20, 48, 38, tzinfo=tzutc()),
#         'DeleteOnTermination': False,
#         'Status': 'attached',
#         'VolumeId': 'vol-146fadc4'}}],
#      'ClientToken': 'vLCQR1463519627573',
#      'EbsOptimized': False,
#      'Hypervisor': 'xen',
#      'ImageId': 'ami-fce3c696',
#      'InstanceId': 'i-0ea51fd37eb61ca9a',
#      'InstanceType': 't2.medium',
#      'KeyName': 'lstead-aws',
#      'LaunchTime': datetime.datetime(2016, 5, 18, 20, 48, 52, tzinfo=tzutc()),
#      'Monitoring': {'State': 'disabled'},
#      'NetworkInterfaces': [{'Association': {'IpOwnerId': '674776699098',
#         'PublicDnsName': 'ec2-52-203-160-68.compute-1.amazonaws.com',
#         'PublicIp': '52.203.160.68'},
#        'Attachment': {'AttachTime': datetime.datetime(2016, 5, 17, 21, 13, 48, tzinfo=tzutc()),
#         'AttachmentId': 'eni-attach-222778d2',
#         'DeleteOnTermination': True,
#         'DeviceIndex': 0,
#         'Status': 'attached'},
#        'Description': 'Primary network interface',
#        'Groups': [{'GroupId': 'sg-9e8e5ce5', 'GroupName': 'launch-wizard-7'}],
#        'Ipv6Addresses': [],
#        'MacAddress': '12:1a:a2:08:06:5b',
#        'NetworkInterfaceId': 'eni-34ee9613',
#        'OwnerId': '674776699098',
#        'PrivateDnsName': 'ip-172-31-59-18.ec2.internal',
#        'PrivateIpAddress': '172.31.59.18',
#        'PrivateIpAddresses': [{'Association': {'IpOwnerId': '674776699098',
#           'PublicDnsName': 'ec2-52-203-160-68.compute-1.amazonaws.com',
#           'PublicIp': '52.203.160.68'},
#          'Primary': True,
#          'PrivateDnsName': 'ip-172-31-59-18.ec2.internal',
#          'PrivateIpAddress': '172.31.59.18'}],
#        'SourceDestCheck': True,
#        'Status': 'in-use',
#        'SubnetId': 'subnet-881a9aa2',
#        'VpcId': 'vpc-dc8493b8'}],
#      'Placement': {'AvailabilityZone': 'us-east-1c',
#       'GroupName': '',
#       'Tenancy': 'default'},
#      'PrivateDnsName': 'ip-172-31-59-18.ec2.internal',
#      'PrivateIpAddress': '172.31.59.18',
#      'ProductCodes': [],
#      'PublicDnsName': 'ec2-52-203-160-68.compute-1.amazonaws.com',
#      'PublicIpAddress': '52.203.160.68',
#      'RootDeviceName': '/dev/sda1',
#      'RootDeviceType': 'ebs',
#      'SecurityGroups': [{'GroupId': 'sg-9e8e5ce5',
#        'GroupName': 'launch-wizard-7'}],
#      'SourceDestCheck': True,
#      'State': {'Code': 16, 'Name': 'running'},
#      'StateTransitionReason': '',
#      'SubnetId': 'subnet-881a9aa2',
#      'Tags': [{'Key': 'Name', 'Value': 'nginx-nfs'},
#       {'Key': 'opsworks:layer:nfs-nginx', 'Value': 'nfs-nginx'},
#       {'Key': 'opsworks:stack', 'Value': 'Default Stack'},
#       {'Key': 'opsworks:instance', 'Value': 'ip-172-31-59-18'}],
#      'VirtualizationType': 'hvm',
#      'VpcId': 'vpc-dc8493b8'}],
#    'OwnerId': '674776699098',
#    'ReservationId': 'r-0270c5272a1993d3e'},
#   {'Groups': [],
#    'Instances': [{'AmiLaunchIndex': 0,
#      'Architecture': 'x86_64',
#      'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#        'Ebs': {'AttachTime': datetime.datetime(2016, 5, 17, 14, 55, 53, tzinfo=tzutc()),
#         'DeleteOnTermination': True,
#         'Status': 'attached',
#         'VolumeId': 'vol-ebc03b3b'}},
#       {'DeviceName': '/dev/sdf',
#        'Ebs': {'AttachTime': datetime.datetime(2016, 5, 18, 20, 47, 58, tzinfo=tzutc()),
#         'DeleteOnTermination': False,
#         'Status': 'attached',
#         'VolumeId': 'vol-d06cae00'}}],
#      'ClientToken': '146349693967329059',
#      'EbsOptimized': False,
#      'Hypervisor': 'xen',
#      'ImageId': 'ami-e0b3568d',
#      'InstanceId': 'i-015b9e0f08e6cae43',
#      'InstanceType': 'g2.2xlarge',
#      'KeyName': 'lstead-aws',
#      'LaunchTime': datetime.datetime(2016, 10, 25, 13, 7, 3, tzinfo=tzutc()),
#      'Monitoring': {'State': 'disabled'},
#      'NetworkInterfaces': [{'Association': {'IpOwnerId': '674776699098',
#         'PublicDnsName': 'ec2-52-201-56-125.compute-1.amazonaws.com',
#         'PublicIp': '52.201.56.125'},
#        'Attachment': {'AttachTime': datetime.datetime(2016, 5, 17, 14, 55, 52, tzinfo=tzutc()),
#         'AttachmentId': 'eni-attach-c7a6f437',
#         'DeleteOnTermination': True,
#         'DeviceIndex': 0,
#         'Status': 'attached'},
#        'Description': 'Primary network interface',
#        'Groups': [{'GroupId': 'sg-4983a931',
#          'GroupName': 'Bitfusion Ubuntu 14 Cuda 7 -GPU--0-01--AutogenByAWSMP-'}],
#        'Ipv6Addresses': [],
#        'MacAddress': '12:a6:79:e0:1c:df',
#        'NetworkInterfaceId': 'eni-6bc2bd4c',
#        'OwnerId': '674776699098',
#        'PrivateDnsName': 'ip-172-31-57-246.ec2.internal',
#        'PrivateIpAddress': '172.31.57.246',
#        'PrivateIpAddresses': [{'Association': {'IpOwnerId': '674776699098',
#           'PublicDnsName': 'ec2-52-201-56-125.compute-1.amazonaws.com',
#           'PublicIp': '52.201.56.125'},
#          'Primary': True,
#          'PrivateDnsName': 'ip-172-31-57-246.ec2.internal',
#          'PrivateIpAddress': '172.31.57.246'}],
#        'SourceDestCheck': True,
#        'Status': 'in-use',
#        'SubnetId': 'subnet-881a9aa2',
#        'VpcId': 'vpc-dc8493b8'}],
#      'Placement': {'AvailabilityZone': 'us-east-1c',
#       'GroupName': '',
#       'Tenancy': 'default'},
#      'PrivateDnsName': 'ip-172-31-57-246.ec2.internal',
#      'PrivateIpAddress': '172.31.57.246',
#      'ProductCodes': [{'ProductCodeId': 'd7b4x2lsogqounxst4jkrmdag',
#        'ProductCodeType': 'marketplace'}],
#      'PublicDnsName': 'ec2-52-201-56-125.compute-1.amazonaws.com',
#      'PublicIpAddress': '52.201.56.125',
#      'RootDeviceName': '/dev/sda1',
#      'RootDeviceType': 'ebs',
#      'SecurityGroups': [{'GroupId': 'sg-4983a931',
#        'GroupName': 'Bitfusion Ubuntu 14 Cuda 7 -GPU--0-01--AutogenByAWSMP-'}],
#      'SourceDestCheck': True,
#      'State': {'Code': 16, 'Name': 'running'},
#      'StateTransitionReason': '',
#      'SubnetId': 'subnet-881a9aa2',
#      'Tags': [{'Key': 'Role', 'Value': 'development'},
#       {'Key': 'opsworks:layer:gpu', 'Value': 'Backend GPU Machine'},
#       {'Key': 'Name', 'Value': 'loptix-dev'},
#       {'Key': 'opsworks:instance', 'Value': 'ip-172-31-57-246'},
#       {'Key': 'opsworks:stack', 'Value': 'Default Stack'}],
#      'VirtualizationType': 'hvm',
#      'VpcId': 'vpc-dc8493b8'}],
#    'OwnerId': '674776699098',
#    'ReservationId': 'r-09c7613e06354a10b'},
#   {'Groups': [],
#    'Instances': [{'AmiLaunchIndex': 0,
#      'Architecture': 'x86_64',
#      'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#        'Ebs': {'AttachTime': datetime.datetime(2016, 5, 26, 19, 38, 6, tzinfo=tzutc()),
#         'DeleteOnTermination': True,
#         'Status': 'attached',
#         'VolumeId': 'vol-f0f3a15b'}}],
#      'ClientToken': 'FSpFx1464291484490',
#      'EbsOptimized': False,
#      'Hypervisor': 'xen',
#      'ImageId': 'ami-e0b3568d',
#      'InstanceId': 'i-04fe4b1ff191e4d99',
#      'InstanceType': 'g2.2xlarge',
#      'KeyName': 'lstead-aws',
#      'LaunchTime': datetime.datetime(2016, 10, 19, 0, 16, 47, tzinfo=tzutc()),
#      'Monitoring': {'State': 'disabled'},
#      'NetworkInterfaces': [{'Association': {'IpOwnerId': 'amazon',
#         'PublicDnsName': 'ec2-54-227-184-215.compute-1.amazonaws.com',
#         'PublicIp': '54.227.184.215'},
#        'Attachment': {'AttachTime': datetime.datetime(2016, 5, 26, 19, 38, 5, tzinfo=tzutc()),
#         'AttachmentId': 'eni-attach-6361dcb8',
#         'DeleteOnTermination': True,
#         'DeviceIndex': 0,
#         'Status': 'attached'},
#        'Description': '',
#        'Groups': [{'GroupId': 'sg-5ffb5224', 'GroupName': 'gpu-backends'}],
#        'Ipv6Addresses': [],
#        'MacAddress': '0a:05:1d:21:1d:97',
#        'NetworkInterfaceId': 'eni-934cd0d0',
#        'OwnerId': '674776699098',
#        'PrivateDnsName': 'ip-172-31-12-16.ec2.internal',
#        'PrivateIpAddress': '172.31.12.16',
#        'PrivateIpAddresses': [{'Association': {'IpOwnerId': 'amazon',
#           'PublicDnsName': 'ec2-54-227-184-215.compute-1.amazonaws.com',
#           'PublicIp': '54.227.184.215'},
#          'Primary': True,
#          'PrivateDnsName': 'ip-172-31-12-16.ec2.internal',
#          'PrivateIpAddress': '172.31.12.16'}],
#        'SourceDestCheck': True,
#        'Status': 'in-use',
#        'SubnetId': 'subnet-b2e99ac4',
#        'VpcId': 'vpc-dc8493b8'}],
#      'Placement': {'AvailabilityZone': 'us-east-1d',
#       'GroupName': '',
#       'Tenancy': 'default'},
#      'PrivateDnsName': 'ip-172-31-12-16.ec2.internal',
#      'PrivateIpAddress': '172.31.12.16',
#      'ProductCodes': [{'ProductCodeId': 'd7b4x2lsogqounxst4jkrmdag',
#        'ProductCodeType': 'marketplace'}],
#      'PublicDnsName': 'ec2-54-227-184-215.compute-1.amazonaws.com',
#      'PublicIpAddress': '54.227.184.215',
#      'RootDeviceName': '/dev/sda1',
#      'RootDeviceType': 'ebs',
#      'SecurityGroups': [{'GroupId': 'sg-5ffb5224',
#        'GroupName': 'gpu-backends'}],
#      'SourceDestCheck': True,
#      'State': {'Code': 16, 'Name': 'running'},
#      'StateTransitionReason': '',
#      'SubnetId': 'subnet-b2e99ac4',
#      'Tags': [{'Key': 'opsworks:stack', 'Value': 'Default Stack'},
#       {'Key': 'Name', 'Value': 'loptix1'},
#       {'Key': 'opsworks:layer:gpu', 'Value': 'Backend GPU Machine'},
#       {'Key': 'opsworks:instance', 'Value': 'loptix1'},
#       {'Key': 'Role', 'Value': 'production'}],
#      'VirtualizationType': 'hvm',
#      'VpcId': 'vpc-dc8493b8'}],
#    'OwnerId': '674776699098',
#    'ReservationId': 'r-00923a48ab8a83bce'},
#   {'Groups': [],
#    'Instances': [{'AmiLaunchIndex': 0,
#      'Architecture': 'x86_64',
#      'BlockDeviceMappings': [{'DeviceName': '/dev/xvda',
#        'Ebs': {'AttachTime': datetime.datetime(2017, 3, 2, 2, 10, 37, tzinfo=tzutc()),
#         'DeleteOnTermination': True,
#         'Status': 'attached',
#         'VolumeId': 'vol-035d3b4ec7caf5017'}}],
#      'ClientToken': '',
#      'EbsOptimized': False,
#      'Hypervisor': 'xen',
#      'ImageId': 'ami-08111162',
#      'InstanceId': 'i-077110dd2fb5717a5',
#      'InstanceType': 't2.micro',
#      'LaunchTime': datetime.datetime(2017, 3, 2, 2, 10, 36, tzinfo=tzutc()),
#      'Monitoring': {'State': 'disabled'},
#      'NetworkInterfaces': [{'Association': {'IpOwnerId': 'amazon',
#         'PublicDnsName': 'ec2-52-91-103-161.compute-1.amazonaws.com',
#         'PublicIp': '52.91.103.161'},
#        'Attachment': {'AttachTime': datetime.datetime(2017, 3, 2, 2, 10, 36, tzinfo=tzutc()),
#         'AttachmentId': 'eni-attach-f8e35dd5',
#         'DeleteOnTermination': True,
#         'DeviceIndex': 0,
#         'Status': 'attached'},
#        'Description': '',
#        'Groups': [{'GroupId': 'sg-f187a289', 'GroupName': 'default'}],
#        'Ipv6Addresses': [],
#        'MacAddress': '12:74:22:a2:0e:34',
#        'NetworkInterfaceId': 'eni-79439e8c',
#        'OwnerId': '674776699098',
#        'PrivateDnsName': 'ip-172-31-49-148.ec2.internal',
#        'PrivateIpAddress': '172.31.49.148',
#        'PrivateIpAddresses': [{'Association': {'IpOwnerId': 'amazon',
#           'PublicDnsName': 'ec2-52-91-103-161.compute-1.amazonaws.com',
#           'PublicIp': '52.91.103.161'},
#          'Primary': True,
#          'PrivateDnsName': 'ip-172-31-49-148.ec2.internal',
#          'PrivateIpAddress': '172.31.49.148'}],
#        'SourceDestCheck': True,
#        'Status': 'in-use',
#        'SubnetId': 'subnet-881a9aa2',
#        'VpcId': 'vpc-dc8493b8'}],
#      'Placement': {'AvailabilityZone': 'us-east-1c',
#       'GroupName': '',
#       'Tenancy': 'default'},
#      'PrivateDnsName': 'ip-172-31-49-148.ec2.internal',
#      'PrivateIpAddress': '172.31.49.148',
#      'ProductCodes': [],
#      'PublicDnsName': 'ec2-52-91-103-161.compute-1.amazonaws.com',
#      'PublicIpAddress': '52.91.103.161',
#      'RootDeviceName': '/dev/xvda',
#      'RootDeviceType': 'ebs',
#      'SecurityGroups': [{'GroupId': 'sg-f187a289', 'GroupName': 'default'}],
#      'SourceDestCheck': True,
#      'State': {'Code': 16, 'Name': 'running'},
#      'StateTransitionReason': '',
#      'SubnetId': 'subnet-881a9aa2',
#      'VirtualizationType': 'hvm',
#      'VpcId': 'vpc-dc8493b8'},
#     {'AmiLaunchIndex': 1,
#      'Architecture': 'x86_64',
#      'BlockDeviceMappings': [{'DeviceName': '/dev/xvda',
#        'Ebs': {'AttachTime': datetime.datetime(2017, 3, 2, 2, 10, 37, tzinfo=tzutc()),
#         'DeleteOnTermination': True,
#         'Status': 'attached',
#         'VolumeId': 'vol-0afac8f91cfb61e7c'}}],
#      'ClientToken': '',
#      'EbsOptimized': False,
#      'Hypervisor': 'xen',
#      'ImageId': 'ami-08111162',
#      'InstanceId': 'i-037340254b06008f5',
#      'InstanceType': 't2.micro',
#      'LaunchTime': datetime.datetime(2017, 3, 2, 2, 10, 36, tzinfo=tzutc()),
#      'Monitoring': {'State': 'disabled'},
#      'NetworkInterfaces': [{'Association': {'IpOwnerId': 'amazon',
#         'PublicDnsName': 'ec2-52-207-211-70.compute-1.amazonaws.com',
#         'PublicIp': '52.207.211.70'},
#        'Attachment': {'AttachTime': datetime.datetime(2017, 3, 2, 2, 10, 36, tzinfo=tzutc()),
#         'AttachmentId': 'eni-attach-e6e35dcb',
#         'DeleteOnTermination': True,
#         'DeviceIndex': 0,
#         'Status': 'attached'},
#        'Description': '',
#        'Groups': [{'GroupId': 'sg-f187a289', 'GroupName': 'default'}],
#        'Ipv6Addresses': [],
#        'MacAddress': '12:65:f6:fb:1b:86',
#        'NetworkInterfaceId': 'eni-78439e8d',
#        'OwnerId': '674776699098',
#        'PrivateDnsName': 'ip-172-31-55-187.ec2.internal',
#        'PrivateIpAddress': '172.31.55.187',
#        'PrivateIpAddresses': [{'Association': {'IpOwnerId': 'amazon',
#           'PublicDnsName': 'ec2-52-207-211-70.compute-1.amazonaws.com',
#           'PublicIp': '52.207.211.70'},
#          'Primary': True,
#          'PrivateDnsName': 'ip-172-31-55-187.ec2.internal',
#          'PrivateIpAddress': '172.31.55.187'}],
#        'SourceDestCheck': True,
#        'Status': 'in-use',
#        'SubnetId': 'subnet-881a9aa2',
#        'VpcId': 'vpc-dc8493b8'}],
#      'Placement': {'AvailabilityZone': 'us-east-1c',
#       'GroupName': '',
#       'Tenancy': 'default'},
#      'PrivateDnsName': 'ip-172-31-55-187.ec2.internal',
#      'PrivateIpAddress': '172.31.55.187',
#      'ProductCodes': [],
#      'PublicDnsName': 'ec2-52-207-211-70.compute-1.amazonaws.com',
#      'PublicIpAddress': '52.207.211.70',
#      'RootDeviceName': '/dev/xvda',
#      'RootDeviceType': 'ebs',
#      'SecurityGroups': [{'GroupId': 'sg-f187a289', 'GroupName': 'default'}],
#      'SourceDestCheck': True,
#      'State': {'Code': 16, 'Name': 'running'},
#      'StateTransitionReason': '',
#      'SubnetId': 'subnet-881a9aa2',
#      'VirtualizationType': 'hvm',
#      'VpcId': 'vpc-dc8493b8'}],
#    'OwnerId': '674776699098',
#    'ReservationId': 'r-02a2be17511a34742'}],
#  'ResponseMetadata': {'HTTPHeaders': {'content-type': 'text/xml;charset=UTF-8',
#    'date': 'Thu, 02 Mar 2017 02:11:01 GMT',
#    'server': 'AmazonEC2',
#    'transfer-encoding': 'chunked',
#    'vary': 'Accept-Encoding'},
#   'HTTPStatusCode': 200,
#   'RequestId': 'f27843e5-e808-4fb9-b56c-6076e5009547',
#   'RetryAttempts': 0}}

# %%
di2 = di['Reservations']
di2
# Out:
# [{'Groups': [],
#   'Instances': [{'AmiLaunchIndex': 0,
#     'Architecture': 'x86_64',
#     'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#       'Ebs': {'AttachTime': datetime.datetime(2016, 5, 17, 21, 13, 48, tzinfo=tzutc()),
#        'DeleteOnTermination': True,
#        'Status': 'attached',
#        'VolumeId': 'vol-de3efb0e'}},
#      {'DeviceName': '/dev/sdf',
#       'Ebs': {'AttachTime': datetime.datetime(2016, 5, 18, 20, 48, 38, tzinfo=tzutc()),
#        'DeleteOnTermination': False,
#        'Status': 'attached',
#        'VolumeId': 'vol-146fadc4'}}],
#     'ClientToken': 'vLCQR1463519627573',
#     'EbsOptimized': False,
#     'Hypervisor': 'xen',
#     'ImageId': 'ami-fce3c696',
#     'InstanceId': 'i-0ea51fd37eb61ca9a',
#     'InstanceType': 't2.medium',
#     'KeyName': 'lstead-aws',
#     'LaunchTime': datetime.datetime(2016, 5, 18, 20, 48, 52, tzinfo=tzutc()),
#     'Monitoring': {'State': 'disabled'},
#     'NetworkInterfaces': [{'Association': {'IpOwnerId': '674776699098',
#        'PublicDnsName': 'ec2-52-203-160-68.compute-1.amazonaws.com',
#        'PublicIp': '52.203.160.68'},
#       'Attachment': {'AttachTime': datetime.datetime(2016, 5, 17, 21, 13, 48, tzinfo=tzutc()),
#        'AttachmentId': 'eni-attach-222778d2',
#        'DeleteOnTermination': True,
#        'DeviceIndex': 0,
#        'Status': 'attached'},
#       'Description': 'Primary network interface',
#       'Groups': [{'GroupId': 'sg-9e8e5ce5', 'GroupName': 'launch-wizard-7'}],
#       'Ipv6Addresses': [],
#       'MacAddress': '12:1a:a2:08:06:5b',
#       'NetworkInterfaceId': 'eni-34ee9613',
#       'OwnerId': '674776699098',
#       'PrivateDnsName': 'ip-172-31-59-18.ec2.internal',
#       'PrivateIpAddress': '172.31.59.18',
#       'PrivateIpAddresses': [{'Association': {'IpOwnerId': '674776699098',
#          'PublicDnsName': 'ec2-52-203-160-68.compute-1.amazonaws.com',
#          'PublicIp': '52.203.160.68'},
#         'Primary': True,
#         'PrivateDnsName': 'ip-172-31-59-18.ec2.internal',
#         'PrivateIpAddress': '172.31.59.18'}],
#       'SourceDestCheck': True,
#       'Status': 'in-use',
#       'SubnetId': 'subnet-881a9aa2',
#       'VpcId': 'vpc-dc8493b8'}],
#     'Placement': {'AvailabilityZone': 'us-east-1c',
#      'GroupName': '',
#      'Tenancy': 'default'},
#     'PrivateDnsName': 'ip-172-31-59-18.ec2.internal',
#     'PrivateIpAddress': '172.31.59.18',
#     'ProductCodes': [],
#     'PublicDnsName': 'ec2-52-203-160-68.compute-1.amazonaws.com',
#     'PublicIpAddress': '52.203.160.68',
#     'RootDeviceName': '/dev/sda1',
#     'RootDeviceType': 'ebs',
#     'SecurityGroups': [{'GroupId': 'sg-9e8e5ce5',
#       'GroupName': 'launch-wizard-7'}],
#     'SourceDestCheck': True,
#     'State': {'Code': 16, 'Name': 'running'},
#     'StateTransitionReason': '',
#     'SubnetId': 'subnet-881a9aa2',
#     'Tags': [{'Key': 'Name', 'Value': 'nginx-nfs'},
#      {'Key': 'opsworks:layer:nfs-nginx', 'Value': 'nfs-nginx'},
#      {'Key': 'opsworks:stack', 'Value': 'Default Stack'},
#      {'Key': 'opsworks:instance', 'Value': 'ip-172-31-59-18'}],
#     'VirtualizationType': 'hvm',
#     'VpcId': 'vpc-dc8493b8'}],
#   'OwnerId': '674776699098',
#   'ReservationId': 'r-0270c5272a1993d3e'},
#  {'Groups': [],
#   'Instances': [{'AmiLaunchIndex': 0,
#     'Architecture': 'x86_64',
#     'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#       'Ebs': {'AttachTime': datetime.datetime(2016, 5, 17, 14, 55, 53, tzinfo=tzutc()),
#        'DeleteOnTermination': True,
#        'Status': 'attached',
#        'VolumeId': 'vol-ebc03b3b'}},
#      {'DeviceName': '/dev/sdf',
#       'Ebs': {'AttachTime': datetime.datetime(2016, 5, 18, 20, 47, 58, tzinfo=tzutc()),
#        'DeleteOnTermination': False,
#        'Status': 'attached',
#        'VolumeId': 'vol-d06cae00'}}],
#     'ClientToken': '146349693967329059',
#     'EbsOptimized': False,
#     'Hypervisor': 'xen',
#     'ImageId': 'ami-e0b3568d',
#     'InstanceId': 'i-015b9e0f08e6cae43',
#     'InstanceType': 'g2.2xlarge',
#     'KeyName': 'lstead-aws',
#     'LaunchTime': datetime.datetime(2016, 10, 25, 13, 7, 3, tzinfo=tzutc()),
#     'Monitoring': {'State': 'disabled'},
#     'NetworkInterfaces': [{'Association': {'IpOwnerId': '674776699098',
#        'PublicDnsName': 'ec2-52-201-56-125.compute-1.amazonaws.com',
#        'PublicIp': '52.201.56.125'},
#       'Attachment': {'AttachTime': datetime.datetime(2016, 5, 17, 14, 55, 52, tzinfo=tzutc()),
#        'AttachmentId': 'eni-attach-c7a6f437',
#        'DeleteOnTermination': True,
#        'DeviceIndex': 0,
#        'Status': 'attached'},
#       'Description': 'Primary network interface',
#       'Groups': [{'GroupId': 'sg-4983a931',
#         'GroupName': 'Bitfusion Ubuntu 14 Cuda 7 -GPU--0-01--AutogenByAWSMP-'}],
#       'Ipv6Addresses': [],
#       'MacAddress': '12:a6:79:e0:1c:df',
#       'NetworkInterfaceId': 'eni-6bc2bd4c',
#       'OwnerId': '674776699098',
#       'PrivateDnsName': 'ip-172-31-57-246.ec2.internal',
#       'PrivateIpAddress': '172.31.57.246',
#       'PrivateIpAddresses': [{'Association': {'IpOwnerId': '674776699098',
#          'PublicDnsName': 'ec2-52-201-56-125.compute-1.amazonaws.com',
#          'PublicIp': '52.201.56.125'},
#         'Primary': True,
#         'PrivateDnsName': 'ip-172-31-57-246.ec2.internal',
#         'PrivateIpAddress': '172.31.57.246'}],
#       'SourceDestCheck': True,
#       'Status': 'in-use',
#       'SubnetId': 'subnet-881a9aa2',
#       'VpcId': 'vpc-dc8493b8'}],
#     'Placement': {'AvailabilityZone': 'us-east-1c',
#      'GroupName': '',
#      'Tenancy': 'default'},
#     'PrivateDnsName': 'ip-172-31-57-246.ec2.internal',
#     'PrivateIpAddress': '172.31.57.246',
#     'ProductCodes': [{'ProductCodeId': 'd7b4x2lsogqounxst4jkrmdag',
#       'ProductCodeType': 'marketplace'}],
#     'PublicDnsName': 'ec2-52-201-56-125.compute-1.amazonaws.com',
#     'PublicIpAddress': '52.201.56.125',
#     'RootDeviceName': '/dev/sda1',
#     'RootDeviceType': 'ebs',
#     'SecurityGroups': [{'GroupId': 'sg-4983a931',
#       'GroupName': 'Bitfusion Ubuntu 14 Cuda 7 -GPU--0-01--AutogenByAWSMP-'}],
#     'SourceDestCheck': True,
#     'State': {'Code': 16, 'Name': 'running'},
#     'StateTransitionReason': '',
#     'SubnetId': 'subnet-881a9aa2',
#     'Tags': [{'Key': 'Role', 'Value': 'development'},
#      {'Key': 'opsworks:layer:gpu', 'Value': 'Backend GPU Machine'},
#      {'Key': 'Name', 'Value': 'loptix-dev'},
#      {'Key': 'opsworks:instance', 'Value': 'ip-172-31-57-246'},
#      {'Key': 'opsworks:stack', 'Value': 'Default Stack'}],
#     'VirtualizationType': 'hvm',
#     'VpcId': 'vpc-dc8493b8'}],
#   'OwnerId': '674776699098',
#   'ReservationId': 'r-09c7613e06354a10b'},
#  {'Groups': [],
#   'Instances': [{'AmiLaunchIndex': 0,
#     'Architecture': 'x86_64',
#     'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#       'Ebs': {'AttachTime': datetime.datetime(2016, 5, 26, 19, 38, 6, tzinfo=tzutc()),
#        'DeleteOnTermination': True,
#        'Status': 'attached',
#        'VolumeId': 'vol-f0f3a15b'}}],
#     'ClientToken': 'FSpFx1464291484490',
#     'EbsOptimized': False,
#     'Hypervisor': 'xen',
#     'ImageId': 'ami-e0b3568d',
#     'InstanceId': 'i-04fe4b1ff191e4d99',
#     'InstanceType': 'g2.2xlarge',
#     'KeyName': 'lstead-aws',
#     'LaunchTime': datetime.datetime(2016, 10, 19, 0, 16, 47, tzinfo=tzutc()),
#     'Monitoring': {'State': 'disabled'},
#     'NetworkInterfaces': [{'Association': {'IpOwnerId': 'amazon',
#        'PublicDnsName': 'ec2-54-227-184-215.compute-1.amazonaws.com',
#        'PublicIp': '54.227.184.215'},
#       'Attachment': {'AttachTime': datetime.datetime(2016, 5, 26, 19, 38, 5, tzinfo=tzutc()),
#        'AttachmentId': 'eni-attach-6361dcb8',
#        'DeleteOnTermination': True,
#        'DeviceIndex': 0,
#        'Status': 'attached'},
#       'Description': '',
#       'Groups': [{'GroupId': 'sg-5ffb5224', 'GroupName': 'gpu-backends'}],
#       'Ipv6Addresses': [],
#       'MacAddress': '0a:05:1d:21:1d:97',
#       'NetworkInterfaceId': 'eni-934cd0d0',
#       'OwnerId': '674776699098',
#       'PrivateDnsName': 'ip-172-31-12-16.ec2.internal',
#       'PrivateIpAddress': '172.31.12.16',
#       'PrivateIpAddresses': [{'Association': {'IpOwnerId': 'amazon',
#          'PublicDnsName': 'ec2-54-227-184-215.compute-1.amazonaws.com',
#          'PublicIp': '54.227.184.215'},
#         'Primary': True,
#         'PrivateDnsName': 'ip-172-31-12-16.ec2.internal',
#         'PrivateIpAddress': '172.31.12.16'}],
#       'SourceDestCheck': True,
#       'Status': 'in-use',
#       'SubnetId': 'subnet-b2e99ac4',
#       'VpcId': 'vpc-dc8493b8'}],
#     'Placement': {'AvailabilityZone': 'us-east-1d',
#      'GroupName': '',
#      'Tenancy': 'default'},
#     'PrivateDnsName': 'ip-172-31-12-16.ec2.internal',
#     'PrivateIpAddress': '172.31.12.16',
#     'ProductCodes': [{'ProductCodeId': 'd7b4x2lsogqounxst4jkrmdag',
#       'ProductCodeType': 'marketplace'}],
#     'PublicDnsName': 'ec2-54-227-184-215.compute-1.amazonaws.com',
#     'PublicIpAddress': '54.227.184.215',
#     'RootDeviceName': '/dev/sda1',
#     'RootDeviceType': 'ebs',
#     'SecurityGroups': [{'GroupId': 'sg-5ffb5224',
#       'GroupName': 'gpu-backends'}],
#     'SourceDestCheck': True,
#     'State': {'Code': 16, 'Name': 'running'},
#     'StateTransitionReason': '',
#     'SubnetId': 'subnet-b2e99ac4',
#     'Tags': [{'Key': 'opsworks:stack', 'Value': 'Default Stack'},
#      {'Key': 'Name', 'Value': 'loptix1'},
#      {'Key': 'opsworks:layer:gpu', 'Value': 'Backend GPU Machine'},
#      {'Key': 'opsworks:instance', 'Value': 'loptix1'},
#      {'Key': 'Role', 'Value': 'production'}],
#     'VirtualizationType': 'hvm',
#     'VpcId': 'vpc-dc8493b8'}],
#   'OwnerId': '674776699098',
#   'ReservationId': 'r-00923a48ab8a83bce'},
#  {'Groups': [],
#   'Instances': [{'AmiLaunchIndex': 0,
#     'Architecture': 'x86_64',
#     'BlockDeviceMappings': [{'DeviceName': '/dev/xvda',
#       'Ebs': {'AttachTime': datetime.datetime(2017, 3, 2, 2, 10, 37, tzinfo=tzutc()),
#        'DeleteOnTermination': True,
#        'Status': 'attached',
#        'VolumeId': 'vol-035d3b4ec7caf5017'}}],
#     'ClientToken': '',
#     'EbsOptimized': False,
#     'Hypervisor': 'xen',
#     'ImageId': 'ami-08111162',
#     'InstanceId': 'i-077110dd2fb5717a5',
#     'InstanceType': 't2.micro',
#     'LaunchTime': datetime.datetime(2017, 3, 2, 2, 10, 36, tzinfo=tzutc()),
#     'Monitoring': {'State': 'disabled'},
#     'NetworkInterfaces': [{'Association': {'IpOwnerId': 'amazon',
#        'PublicDnsName': 'ec2-52-91-103-161.compute-1.amazonaws.com',
#        'PublicIp': '52.91.103.161'},
#       'Attachment': {'AttachTime': datetime.datetime(2017, 3, 2, 2, 10, 36, tzinfo=tzutc()),
#        'AttachmentId': 'eni-attach-f8e35dd5',
#        'DeleteOnTermination': True,
#        'DeviceIndex': 0,
#        'Status': 'attached'},
#       'Description': '',
#       'Groups': [{'GroupId': 'sg-f187a289', 'GroupName': 'default'}],
#       'Ipv6Addresses': [],
#       'MacAddress': '12:74:22:a2:0e:34',
#       'NetworkInterfaceId': 'eni-79439e8c',
#       'OwnerId': '674776699098',
#       'PrivateDnsName': 'ip-172-31-49-148.ec2.internal',
#       'PrivateIpAddress': '172.31.49.148',
#       'PrivateIpAddresses': [{'Association': {'IpOwnerId': 'amazon',
#          'PublicDnsName': 'ec2-52-91-103-161.compute-1.amazonaws.com',
#          'PublicIp': '52.91.103.161'},
#         'Primary': True,
#         'PrivateDnsName': 'ip-172-31-49-148.ec2.internal',
#         'PrivateIpAddress': '172.31.49.148'}],
#       'SourceDestCheck': True,
#       'Status': 'in-use',
#       'SubnetId': 'subnet-881a9aa2',
#       'VpcId': 'vpc-dc8493b8'}],
#     'Placement': {'AvailabilityZone': 'us-east-1c',
#      'GroupName': '',
#      'Tenancy': 'default'},
#     'PrivateDnsName': 'ip-172-31-49-148.ec2.internal',
#     'PrivateIpAddress': '172.31.49.148',
#     'ProductCodes': [],
#     'PublicDnsName': 'ec2-52-91-103-161.compute-1.amazonaws.com',
#     'PublicIpAddress': '52.91.103.161',
#     'RootDeviceName': '/dev/xvda',
#     'RootDeviceType': 'ebs',
#     'SecurityGroups': [{'GroupId': 'sg-f187a289', 'GroupName': 'default'}],
#     'SourceDestCheck': True,
#     'State': {'Code': 16, 'Name': 'running'},
#     'StateTransitionReason': '',
#     'SubnetId': 'subnet-881a9aa2',
#     'VirtualizationType': 'hvm',
#     'VpcId': 'vpc-dc8493b8'},
#    {'AmiLaunchIndex': 1,
#     'Architecture': 'x86_64',
#     'BlockDeviceMappings': [{'DeviceName': '/dev/xvda',
#       'Ebs': {'AttachTime': datetime.datetime(2017, 3, 2, 2, 10, 37, tzinfo=tzutc()),
#        'DeleteOnTermination': True,
#        'Status': 'attached',
#        'VolumeId': 'vol-0afac8f91cfb61e7c'}}],
#     'ClientToken': '',
#     'EbsOptimized': False,
#     'Hypervisor': 'xen',
#     'ImageId': 'ami-08111162',
#     'InstanceId': 'i-037340254b06008f5',
#     'InstanceType': 't2.micro',
#     'LaunchTime': datetime.datetime(2017, 3, 2, 2, 10, 36, tzinfo=tzutc()),
#     'Monitoring': {'State': 'disabled'},
#     'NetworkInterfaces': [{'Association': {'IpOwnerId': 'amazon',
#        'PublicDnsName': 'ec2-52-207-211-70.compute-1.amazonaws.com',
#        'PublicIp': '52.207.211.70'},
#       'Attachment': {'AttachTime': datetime.datetime(2017, 3, 2, 2, 10, 36, tzinfo=tzutc()),
#        'AttachmentId': 'eni-attach-e6e35dcb',
#        'DeleteOnTermination': True,
#        'DeviceIndex': 0,
#        'Status': 'attached'},
#       'Description': '',
#       'Groups': [{'GroupId': 'sg-f187a289', 'GroupName': 'default'}],
#       'Ipv6Addresses': [],
#       'MacAddress': '12:65:f6:fb:1b:86',
#       'NetworkInterfaceId': 'eni-78439e8d',
#       'OwnerId': '674776699098',
#       'PrivateDnsName': 'ip-172-31-55-187.ec2.internal',
#       'PrivateIpAddress': '172.31.55.187',
#       'PrivateIpAddresses': [{'Association': {'IpOwnerId': 'amazon',
#          'PublicDnsName': 'ec2-52-207-211-70.compute-1.amazonaws.com',
#          'PublicIp': '52.207.211.70'},
#         'Primary': True,
#         'PrivateDnsName': 'ip-172-31-55-187.ec2.internal',
#         'PrivateIpAddress': '172.31.55.187'}],
#       'SourceDestCheck': True,
#       'Status': 'in-use',
#       'SubnetId': 'subnet-881a9aa2',
#       'VpcId': 'vpc-dc8493b8'}],
#     'Placement': {'AvailabilityZone': 'us-east-1c',
#      'GroupName': '',
#      'Tenancy': 'default'},
#     'PrivateDnsName': 'ip-172-31-55-187.ec2.internal',
#     'PrivateIpAddress': '172.31.55.187',
#     'ProductCodes': [],
#     'PublicDnsName': 'ec2-52-207-211-70.compute-1.amazonaws.com',
#     'PublicIpAddress': '52.207.211.70',
#     'RootDeviceName': '/dev/xvda',
#     'RootDeviceType': 'ebs',
#     'SecurityGroups': [{'GroupId': 'sg-f187a289', 'GroupName': 'default'}],
#     'SourceDestCheck': True,
#     'State': {'Code': 16, 'Name': 'running'},
#     'StateTransitionReason': '',
#     'SubnetId': 'subnet-881a9aa2',
#     'VirtualizationType': 'hvm',
#     'VpcId': 'vpc-dc8493b8'}],
#   'OwnerId': '674776699098',
#   'ReservationId': 'r-02a2be17511a34742'}]

# %%
di3=di2[0]['Instances']
di3
# Out:
# [{'AmiLaunchIndex': 0,
#   'Architecture': 'x86_64',
#   'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#     'Ebs': {'AttachTime': datetime.datetime(2016, 5, 17, 21, 13, 48, tzinfo=tzutc()),
#      'DeleteOnTermination': True,
#      'Status': 'attached',
#      'VolumeId': 'vol-de3efb0e'}},
#    {'DeviceName': '/dev/sdf',
#     'Ebs': {'AttachTime': datetime.datetime(2016, 5, 18, 20, 48, 38, tzinfo=tzutc()),
#      'DeleteOnTermination': False,
#      'Status': 'attached',
#      'VolumeId': 'vol-146fadc4'}}],
#   'ClientToken': 'vLCQR1463519627573',
#   'EbsOptimized': False,
#   'Hypervisor': 'xen',
#   'ImageId': 'ami-fce3c696',
#   'InstanceId': 'i-0ea51fd37eb61ca9a',
#   'InstanceType': 't2.medium',
#   'KeyName': 'lstead-aws',
#   'LaunchTime': datetime.datetime(2016, 5, 18, 20, 48, 52, tzinfo=tzutc()),
#   'Monitoring': {'State': 'disabled'},
#   'NetworkInterfaces': [{'Association': {'IpOwnerId': '674776699098',
#      'PublicDnsName': 'ec2-52-203-160-68.compute-1.amazonaws.com',
#      'PublicIp': '52.203.160.68'},
#     'Attachment': {'AttachTime': datetime.datetime(2016, 5, 17, 21, 13, 48, tzinfo=tzutc()),
#      'AttachmentId': 'eni-attach-222778d2',
#      'DeleteOnTermination': True,
#      'DeviceIndex': 0,
#      'Status': 'attached'},
#     'Description': 'Primary network interface',
#     'Groups': [{'GroupId': 'sg-9e8e5ce5', 'GroupName': 'launch-wizard-7'}],
#     'Ipv6Addresses': [],
#     'MacAddress': '12:1a:a2:08:06:5b',
#     'NetworkInterfaceId': 'eni-34ee9613',
#     'OwnerId': '674776699098',
#     'PrivateDnsName': 'ip-172-31-59-18.ec2.internal',
#     'PrivateIpAddress': '172.31.59.18',
#     'PrivateIpAddresses': [{'Association': {'IpOwnerId': '674776699098',
#        'PublicDnsName': 'ec2-52-203-160-68.compute-1.amazonaws.com',
#        'PublicIp': '52.203.160.68'},
#       'Primary': True,
#       'PrivateDnsName': 'ip-172-31-59-18.ec2.internal',
#       'PrivateIpAddress': '172.31.59.18'}],
#     'SourceDestCheck': True,
#     'Status': 'in-use',
#     'SubnetId': 'subnet-881a9aa2',
#     'VpcId': 'vpc-dc8493b8'}],
#   'Placement': {'AvailabilityZone': 'us-east-1c',
#    'GroupName': '',
#    'Tenancy': 'default'},
#   'PrivateDnsName': 'ip-172-31-59-18.ec2.internal',
#   'PrivateIpAddress': '172.31.59.18',
#   'ProductCodes': [],
#   'PublicDnsName': 'ec2-52-203-160-68.compute-1.amazonaws.com',
#   'PublicIpAddress': '52.203.160.68',
#   'RootDeviceName': '/dev/sda1',
#   'RootDeviceType': 'ebs',
#   'SecurityGroups': [{'GroupId': 'sg-9e8e5ce5',
#     'GroupName': 'launch-wizard-7'}],
#   'SourceDestCheck': True,
#   'State': {'Code': 16, 'Name': 'running'},
#   'StateTransitionReason': '',
#   'SubnetId': 'subnet-881a9aa2',
#   'Tags': [{'Key': 'Name', 'Value': 'nginx-nfs'},
#    {'Key': 'opsworks:layer:nfs-nginx', 'Value': 'nfs-nginx'},
#    {'Key': 'opsworks:stack', 'Value': 'Default Stack'},
#    {'Key': 'opsworks:instance', 'Value': 'ip-172-31-59-18'}],
#   'VirtualizationType': 'hvm',
#   'VpcId': 'vpc-dc8493b8'}]

# %% [markdown]
# # Google Compute Engine
# - has python interface
# - [docs](https://cloud.google.com/compute/docs/tutorials/python-guide)

# %%
import argparse
import os
import time

import googleapiclient.discovery
from six.moves import input


# [START list_instances]
def list_instances(compute, project, zone):
    result = compute.instances().list(project=project, zone=zone).execute()
    return result['items']
# [END list_instances]


# [START create_instance]
def create_instance(compute, project, zone, name, bucket):
    # Get the latest Debian Jessie image.
    image_response = compute.images().getFromFamily(
        project='debian-cloud', family='debian-8').execute()
    source_disk_image = image_response['selfLink']

    # Configure the machine
    machine_type = "zones/%s/machineTypes/n1-standard-1" % zone
    startup_script = open(
        os.path.join(
            os.path.dirname(__file__), 'startup-script.sh'), 'r').read()
    image_url = "http://storage.googleapis.com/gce-demo-input/photo.jpg"
    image_caption = "Ready for dessert?"

    config = {
        'name': name,
        'machineType': machine_type,

        # Specify the boot disk and the image to use as a source.
        'disks': [
            {
                'boot': True,
                'autoDelete': True,
                'initializeParams': {
                    'sourceImage': source_disk_image,
                }
            }
        ],

        # Specify a network interface with NAT to access the public
        # internet.
        'networkInterfaces': [{
            'network': 'global/networks/default',
            'accessConfigs': [
                {'type': 'ONE_TO_ONE_NAT', 'name': 'External NAT'}
            ]
        }],

        # Allow the instance to access cloud storage and logging.
        'serviceAccounts': [{
            'email': 'default',
            'scopes': [
                'https://www.googleapis.com/auth/devstorage.read_write',
                'https://www.googleapis.com/auth/logging.write'
            ]
        }],

        # Metadata is readable from the instance and allows you to
        # pass configuration from deployment scripts to instances.
        'metadata': {
            'items': [{
                # Startup script is automatically executed by the
                # instance upon startup.
                'key': 'startup-script',
                'value': startup_script
            }, {
                'key': 'url',
                'value': image_url
            }, {
                'key': 'text',
                'value': image_caption
            }, {
                'key': 'bucket',
                'value': bucket
            }]
        }
    }

    return compute.instances().insert(
        project=project,
        zone=zone,
        body=config).execute()
# [END create_instance]


# [START delete_instance]
def delete_instance(compute, project, zone, name):
    return compute.instances().delete(
        project=project,
        zone=zone,
        instance=name).execute()
# [END delete_instance]


# [START wait_for_operation]
def wait_for_operation(compute, project, zone, operation):
    print('Waiting for operation to finish...')
    while True:
        result = compute.zoneOperations().get(
            project=project,
            zone=zone,
            operation=operation).execute()

        if result['status'] == 'DONE':
            print("done.")
            if 'error' in result:
                raise Exception(result['error'])
            return result

        time.sleep(1)
# [END wait_for_operation]


# [START run]
def main(project, bucket, zone, instance_name, wait=True):
    compute = googleapiclient.discovery.build('compute', 'v1')

    print('Creating instance.')

    operation = create_instance(compute, project, zone, instance_name, bucket)
    wait_for_operation(compute, project, zone, operation['name'])

    instances = list_instances(compute, project, zone)

    print('Instances in project %s and zone %s:' % (project, zone))
    for instance in instances:
        print(' - ' + instance['name'])

    print("""
Instance created.
It will take a minute or two for the instance to complete work.
Check this URL: http://storage.googleapis.com/{}/output.png
Once the image is uploaded press enter to delete the instance.
""".format(bucket))

    if wait:
        input()

    print('Deleting instance.')

    operation = delete_instance(compute, project, zone, instance_name)
    wait_for_operation(compute, project, zone, operation['name'])


if __name__ == '__main__':
    parser = argparse.ArgumentParser(
        description=__doc__,
        formatter_class=argparse.RawDescriptionHelpFormatter)
    parser.add_argument('project_id', help='Your Google Cloud project ID.')
    parser.add_argument(
        'bucket_name', help='Your Google Cloud Storage bucket name.')
    parser.add_argument(
        '--zone',
        default='us-central1-f',
        help='Compute Engine zone to deploy to.')
    parser.add_argument(
        '--name', default='demo-instance', help='New instance name.')

    args = parser.parse_args()

    main(args.project_id, args.bucket_name, args.zone, args.name)
# [END run]

# %% [markdown]
# # Microsoft Azure
# - has python interface
# - [docs](https://azure-sdk-for-python.readthedocs.io/en/latest/)

# %% [markdown]
# # OpenStack - Python running the Cloud
# - [OpenStack](http://www.openstack.org) is a huge open source software suite that manages cloud computing clusters
# - primarily written in Python
#     - largest known Python project
#     - almost two million lines of code
# - In use by many research and business groups
# - OpenStack functionality is available via:
#   - [Web Interface](http://www.openstack.org/software/openstack-dashboard/)
#   - [python API](http://docs.openstack.org/user-guide/sdk.html)
