# %%
import requests
import bs4
import math
import time
from bs4 import BeautifulSoup
import os, pickle
import pandas as pd
import numpy as np
os.chdir('C:/coursecode/cs3101/project')

import csv

# %% [markdown]
# ## Using beautiful soup to scrape NBA schedule & game data
#
# - from website www.basketball-reference.com/
# - we need data from seasons 2014-2015, 2015-2016, 2016-2017 to do the simulation

# %%
url_start='http://www.basketball-reference.com/leagues/NBA_'
url_end='.html'

# %%
# function for scraping the data from the url

def get_table(year,month):
    temp=[]
    url_var=str(year)+'_games-'+month
    url=url_start+url_var+url_end
    r=requests.get(url)
    soup=BeautifulSoup(r.content, 'lxml')
    table = soup.find('table', attrs={'class':'suppress_glossary sortable stats_table'})
    table_body = table.find('tbody')
    rows = table_body.find_all('tr')
    for row in rows:
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols]
        temp2=[ele for ele in cols if cols[2] and ele]
        #excluding unfinished games
        if temp2:
            temp.append([year,month]+temp2)
    return temp

# %%
# reading the data from 2015-2017 to data

seasons=[2015,2016,2017]
months=['october', 'november', 'december', 'january', 'february',
       'march', 'april', 'may','june']
data=[]
for i in range(len(seasons)):
    for j in range(len(months)):
        try:
            temps=get_table(seasons[i], months[j])
            #exclude empty months
            if temps:
                data=data+temps
        except:
            print(str(seasons[i])+''+months[j]+' not included')
# Out:
# 2017may not included
# 2017june not included

# %%
# writing data into csv

with open('game_data.csv','w',newline='') as f:
    writer=csv.writer(f,delimiter=',')
    writer.writerow(['year', 'month', 'away_tm','away_score','home_tm','home_score'])
    for item in data:
        #Write item to outcsv
        writer.writerow([item[0], item[1], item[3],item[4],item[5],item[6]])

# %%
game_data=pd.read_csv('game_data.csv')

# %% [markdown]
# ## Basic Calculations

# %%
game_data
# Out:
#       year     month                 away_tm  away_score  \
# 0     2015   october         Houston Rockets         108
# 1     2015   october           Orlando Magic          84
# 2     2015   october        Dallas Mavericks         100
# 3     2015   october           Brooklyn Nets         105
# 4     2015   october         Milwaukee Bucks         106
# 5     2015   october         Detroit Pistons          79
# 6     2015   october      Philadelphia 76ers          91
# 7     2015   october  Minnesota Timberwolves         101
# 8     2015   october      Washington Wizards          95
# 9     2015   october           Chicago Bulls         104
# 10    2015   october      Los Angeles Lakers          99
# 11    2015   october   Oklahoma City Thunder          89
# 12    2015   october   Golden State Warriors          95
# 13    2015   october           Atlanta Hawks         102
# 14    2015   october         Houston Rockets         104
# 15    2015   october         New York Knicks          95
# 16    2015   october               Utah Jazz         102
# 17    2015   october   Oklahoma City Thunder          90
# 18    2015   october         Detroit Pistons          91
# 19    2015   october      Washington Wizards         105
# 20    2015   october     Cleveland Cavaliers         114
# 21    2015   october       Memphis Grizzlies          97
# 22    2015   october    Los Angeles Clippers         118
# 23    2015   october      Philadelphia 76ers          81
# 24    2015   october       San Antonio Spurs          89
# 25    2015   october  Portland Trail Blazers          94
# 26    2015  november          Indiana Pacers          92
# 27    2015  november       Memphis Grizzlies          71
# 28    2015  november           Brooklyn Nets         102
# 3696       San Antonio Spurs          97
# 3697          Boston Celtics         130
# 3698           Chicago Bulls         107
# 3699       Charlotte Hornets         105
# 3700   Golden State Warriors         114
# 3701         Houston Rockets         117
# 3702          Indiana Pacers         117
# 3703      Los Angeles Lakers         130
# 3704         Milwaukee Bucks         100
# 3705           Orlando Magic         115
# 3706      Washington Wizards         129
#
# [3707 rows x 6 columns]

# %%
# get the difference & sum data for further calculation

game_data['diff']=game_data['away_score']-game_data['home_score']
game_data['sum']=game_data['away_score']+game_data['home_score']

# get the list of NBA teams

teams=game_data['home_tm']
teams=teams.drop_duplicates()
teams=teams.values.tolist()

teams_df=pd.DataFrame(data={'name':teams})


# create the battle form (get home team & away team)
temp = []
temp2 = []
for item in teams:
    for item2 in teams:
        if item != item2:
            temp.append(item)
            temp2.append(item2)
games = pd.DataFrame(data={'a_tm':temp, 'h_tm':temp2})

temp3= []
games['Battle'] = games['a_tm']+' vs '+games['h_tm']
games = games.set_index('Battle')
games.index.name=None

# %%
game_data
# Out:
#       year     month                 away_tm  away_score  \
# 0     2015   october         Houston Rockets         108
# 1     2015   october           Orlando Magic          84
# 2     2015   october        Dallas Mavericks         100
# 3     2015   october           Brooklyn Nets         105
# 4     2015   october         Milwaukee Bucks         106
# 5     2015   october         Detroit Pistons          79
# 6     2015   october      Philadelphia 76ers          91
# 7     2015   october  Minnesota Timberwolves         101
# 8     2015   october      Washington Wizards          95
# 9     2015   october           Chicago Bulls         104
# 10    2015   october      Los Angeles Lakers          99
# 11    2015   october   Oklahoma City Thunder          89
# 12    2015   october   Golden State Warriors          95
# 13    2015   october           Atlanta Hawks         102
# 14    2015   october         Houston Rockets         104
# 15    2015   october         New York Knicks          95
# 16    2015   october               Utah Jazz         102
# 17    2015   october   Oklahoma City Thunder          90
# 18    2015   october         Detroit Pistons          91
# 19    2015   october      Washington Wizards         105
# 20    2015   october     Cleveland Cavaliers         114
# 21    2015   october       Memphis Grizzlies          97
# 22    2015   october    Los Angeles Clippers         118
# 23    2015   october      Philadelphia 76ers          81
# 24    2015   october       San Antonio Spurs          89
# 25    2015   october  Portland Trail Blazers          94
# 26    2015  november          Indiana Pacers          92
# 27    2015  november       Memphis Grizzlies          71
# 28    2015  november           Brooklyn Nets         102
# 29    2015  november      Los Angeles Lakers         104
# ...    ...       ...                     ...         ...
# 3677  2017     march   Golden State Warriors         112
# 3678  2017     march    Los Angeles Clippers         133
# 3679  2017     march            Phoenix Suns          97
# 3680  2017     march       San Antonio Spurs         100
# 3681  2017     march       Memphis Grizzlies          82
# 3682  2017     march         Milwaukee Bucks          93
# 3683  2017     march           Chicago Bulls         120
# 3684  2017     march          Indiana Pacers         100
# 3685  2017     march         Detroit Pistons          95
# 3686  2017     march     Cleveland Cavaliers         113
# 3687  2017     march      Philadelphia 76ers          97
# 3688  2017     march       Charlotte Hornets         109
# 3689  2017     march         Milwaukee Bucks         116
# 3690  2017     march         New York Knicks         101
# 3691  2017     march           Atlanta Hawks         100
# 3702          Indiana Pacers         117  242     8
# 3703      Los Angeles Lakers         130  249   -11
# 3704         Milwaukee Bucks         100  197    -3
# 3705           Orlando Magic         115  202   -28
# 3706      Washington Wizards         129  237   -21
#
# [3707 rows x 8 columns]

# %%
teams
# Out:
# ['Los Angeles Lakers',
#  'New Orleans Pelicans',
#  'San Antonio Spurs',
#  'Boston Celtics',
#  'Charlotte Hornets',
#  'Denver Nuggets',
#  'Indiana Pacers',
#  'Memphis Grizzlies',
#  'Miami Heat',
#  'New York Knicks',
#  'Phoenix Suns',
#  'Portland Trail Blazers',
#  'Sacramento Kings',
#  'Toronto Raptors',
#  'Utah Jazz',
#  'Cleveland Cavaliers',
#  'Dallas Mavericks',
#  'Los Angeles Clippers',
#  'Minnesota Timberwolves',
#  'Orlando Magic',
#  'Chicago Bulls',
#  'Milwaukee Bucks',
#  'Atlanta Hawks',
#  'Detroit Pistons',
#  'Golden State Warriors',
#  'Houston Rockets',
#  'Oklahoma City Thunder',
#  'Philadelphia 76ers',
#  'Washington Wizards',
#  'Brooklyn Nets']

# %%
games
# Out:
#                                                               a_tm  \
# Los Angeles Lakers vs New Orleans Pelicans      Los Angeles Lakers
# Los Angeles Lakers vs San Antonio Spurs         Los Angeles Lakers
# Los Angeles Lakers vs Boston Celtics            Los Angeles Lakers
# Los Angeles Lakers vs Charlotte Hornets         Los Angeles Lakers
# Los Angeles Lakers vs Denver Nuggets            Los Angeles Lakers
# Los Angeles Lakers vs Indiana Pacers            Los Angeles Lakers
# Los Angeles Lakers vs Memphis Grizzlies         Los Angeles Lakers
# Los Angeles Lakers vs Miami Heat                Los Angeles Lakers
# Los Angeles Lakers vs New York Knicks           Los Angeles Lakers
# Los Angeles Lakers vs Phoenix Suns              Los Angeles Lakers
# Los Angeles Lakers vs Portland Trail Blazers    Los Angeles Lakers
# Los Angeles Lakers vs Sacramento Kings          Los Angeles Lakers
# Los Angeles Lakers vs Toronto Raptors           Los Angeles Lakers
# Los Angeles Lakers vs Utah Jazz                 Los Angeles Lakers
# Los Angeles Lakers vs Cleveland Cavaliers       Los Angeles Lakers
# Los Angeles Lakers vs Dallas Mavericks          Los Angeles Lakers
# Los Angeles Lakers vs Los Angeles Clippers      Los Angeles Lakers
# Los Angeles Lakers vs Minnesota Timberwolves    Los Angeles Lakers
# Los Angeles Lakers vs Orlando Magic             Los Angeles Lakers
# Los Angeles Lakers vs Chicago Bulls             Los Angeles Lakers
# Los Angeles Lakers vs Milwaukee Bucks           Los Angeles Lakers
# Los Angeles Lakers vs Atlanta Hawks             Los Angeles Lakers
# Los Angeles Lakers vs Detroit Pistons           Los Angeles Lakers
# Los Angeles Lakers vs Golden State Warriors     Los Angeles Lakers
# Los Angeles Lakers vs Houston Rockets           Los Angeles Lakers
# Los Angeles Lakers vs Oklahoma City Thunder     Los Angeles Lakers
# Los Angeles Lakers vs Philadelphia 76ers        Los Angeles Lakers
# Los Angeles Lakers vs Washington Wizards        Los Angeles Lakers
#
# [870 rows x 2 columns]

# %% [markdown]
# ## Simulation Calculations

# %%
# Create class team for calculating the scores & average scores

class Team:
    def __init__(self, name, data):
        self.name=name
        self.data=data
        
        #the lines that include team=name as the away/home team
        self.a_games=data.loc[data['away_tm']==name]
        self.h_games=data.loc[data['home_tm']==name]
        
        #average sum of scores for all games
        self.lmda=data['sum'].mean()
        self.sumvar=data['sum'].var()
        self.diffvar=data['diff'].var()
        
        
    #the average sum of scores scored and conceded by team=name
    def sscore(self):
        tp1=self.a_games['sum'].values.tolist()
        tp1.extend(self.h_games['sum'].values.tolist())
        tp2=np.mean(tp1)
        b_n=1/(1+3/(len(tp1)*self.sumvar))
        tp3=self.lmda+b_n*(tp2-self.lmda)
        return tp3
    
    
    #the average (scored-conceded) per game for team=name
    def difscore(self):
        tp1=self.a_games['diff'].values.tolist()
        tp1.extend([-x for x in self.h_games['diff'].values.tolist()])
        tp2=np.mean(tp1)
        a_n=1/(1+3/(len(tp1)*self.diffvar))
        tp3=a_n*tp2
        return tp3

# %%
c_home=-game_data['diff'].mean()
lmda=game_data['sum'].mean()

# \sigma^2_(\delta G)
diffvar=game_data['diff'].var()

# variance of q_ij
vqij=2*diffvar

# simulation paths
N=1000

# %%
#the \Delta G_i for each team

diff_li=[]
for row in teams_df['name']:
    temp1=Team(row,game_data)
    diff_li.append(temp1.difscore())
teams_df['dlt_g']=diff_li


#the \Sigma G_i for each team

sum_li=[]
for row in teams_df['name']:
    temp1=Team(row,game_data)
    sum_li.append(temp1.sscore())
teams_df['sigma_g']=sum_li
teams_df = teams_df.set_index('name')
teams_df.index.name=None

# %%
teams_df
# Out:
#                             dlt_g     sigma_g
# Los Angeles Lakers      -7.923186  208.033801
# New Orleans Pelicans    -1.837376  205.412488
# San Antonio Spurs        8.062975  200.206496
# Boston Celtics           1.590989  207.210459
# Charlotte Hornets       -0.193403  200.860214
# Denver Nuggets          -2.118499  211.593007
# Indiana Pacers           0.399150  201.419867
# Memphis Grizzlies        0.127482  197.673532
# Miami Heat               0.083995  197.684226
# New York Knicks         -5.283536  201.614518
# Phoenix Suns            -4.379448  211.063096
# Portland Trail Blazers   0.995952  208.940120
# Sacramento Kings        -3.304858  210.533720
# Toronto Raptors          2.953662  204.046183
# Utah Jazz                1.868516  193.369023
# Cleveland Cavaliers      5.057675  205.347817
# Dallas Mavericks        -0.257126  204.265330
# Los Angeles Clippers     4.509444  207.964893
# Minnesota Timberwolves  -4.531603  207.655234
# Orlando Magic           -4.358352  203.025382
# Chicago Bulls            0.333312  202.261130
# Milwaukee Bucks         -1.437920  201.471187
# Atlanta Hawks            2.450230  202.480991
# Detroit Pistons         -0.614067  201.543680
# Golden State Warriors   10.017217  214.515755
# Houston Rockets          2.550228  213.480369
# Oklahoma City Thunder    3.727034  210.248854
# Philadelphia 76ers      -8.257909  202.444999
# Washington Wizards       0.890185  206.191021
# Brooklyn Nets           -5.867376  206.991674

# %%
#game related functions
#tm1 is away team, tm2 is home team

class Game:
    def __init__(self, tm1, tm2):
        self.tm1=tm1
        self.tm2=tm2
        #value of sum of goals g_i+g_j
        self.sgoals=teams_df.ix[self.tm1,'sigma_g']+teams_df.ix[self.tm2,'sigma_g']-lmda
        #mean value of q_ij considering home advantage
        #attention i is away team here
        self.mqij=teams_df.ix[self.tm1,'dlt_g']-teams_df.ix[self.tm2,'dlt_g']-c_home
        self.times=N
        
    #monte carlo simulation for poisson
    def sim_result(self):
        temp=0
        game_mqij=games['mqij'].loc[self.tm1+' vs '+self.tm2]
        game_sgoals=games['sgoals'].loc[self.tm1+' vs '+self.tm2]
        a_mean=(game_mqij+game_sgoals)/2
        h_mean=(game_sgoals-game_mqij)/2
        for i in range(self.times):
            t=0 
            I=0
            while t<=1:
                t=t-1/(a_mean+h_mean)*math.log(np.random.random_sample())
                I=I+1
            temp=temp+I
        g_i=round(temp/self.times*a_mean/(a_mean+h_mean))
        g_j=round(temp/self.times*h_mean/(a_mean+h_mean))
        return g_i, g_j

# %%
teams_df.ix['Los Angeles Lakers','sigma_g']
# Out:
# 208.03380088890358

# %%
#Get for each game the g_i+g_j and the q_ij

temp1=[]
temp2=[]
for index, row in games.iterrows():
    one_game=Game(row['a_tm'],row['h_tm'])
    temp1.append(one_game.sgoals)
    temp2.append(one_game.mqij)
games['sgoals']=temp1
games['mqij']=temp2

# %% [markdown]
# ## Simulation

# %%
#the time needed is 354 sec
#Get for each game the simulation result

def all_sim():
    t1=time.time()
    tp_1=[]
    tp_2=[]
    for index, row in games.iterrows():
        one_game=Game(row['a_tm'],row['h_tm'])
        rlt1, rlt2=one_game.sim_result()
        tp_1.append(rlt1)
        tp_2.append(rlt2)
    games['sim_ascore']=tp_1
    games['sim_hscore']=tp_2
    t2=time.time()-t1
    print('Time used for this simulation is '+str(t2)+' seconds')
    return

# %%
all_sim()
# Out:
# Time used for this simulation is 215.58969116210938 seconds

# %%
games.to_csv("simulation_result.csv")

# %% [markdown]
# ## Model Accuracy Testing

# %%
#test the model
def test():
    temp1=0
    temp2=0
    for index, row in game_data.iterrows():
        real_mar=row['away_score']-row['home_score']
        sim_mar=games['sim_ascore'].loc[row['away_tm']+' vs '+row['home_tm']]-games['sim_hscore'].loc[row['away_tm']+' vs '+row['home_tm']]
        temp1=temp1+int(real_mar*sim_mar>0)
        temp2=temp2+int(math.fabs(real_mar-sim_mar)<=5)
    pick=temp1/len(data)*100
    mar=temp2/len(data)*100
    return pick,mar

pick_accu, mar_accu=test()
print('We pick the right winner for %s percent of time, predict the right margin for %s percent of time'
      %(pick_accu, mar_accu))
# Out:
# We pick the right winner for 65.36282708389534 percent of time, predict the right margin for 36.36363636363637 percent of time

# %% [markdown]
# The accuracy rate of nbagamesim.com is as follows:
# Correct Picks 	48 (70.6%)
# Final Margin within 5 Pts 	20 (29.4%)
#
# Thus we have a better accuracy then them in predicting the scores
# What's more, we have a bigger sample size, thus our result is much more impressive. Cheers.
